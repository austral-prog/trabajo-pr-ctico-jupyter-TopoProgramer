# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).
#
#
# **MAKE SURE TO MAKE A COPY OF THIS ASSIGNMENT IN YOUR OWN REPOSITORY.**

# %% [markdown]
# ---

# %% [markdown]
# # [EXERCISE 1]
# ## Mi nombre es Bruno Almiron
# ##Mi mail es: balmiron@mail.austral.edu.ar
# ![imagen.png](data:image/png;base64,...)
# ##Adjunte esta imagen porque es mi videojuego favorito. Es un juego de puzzle y es bastante complicado por lo que me supone un reto que me gusta afrontar

# %% [markdown]
# #[EXERCISE 5]

# %%
#Create a variable called a and assign it the value 3. Create a variable called b and assign it the value 7
a = 3
b = 7

# %% [markdown]
# #Sum

# %%
print(a+b)
# Out:
# 10

# %% [markdown]
# #Substraction

# %%
print(a-b)
# Out:
# -4

# %% [markdown]
# #Multiplication

# %%
print(a*b)
# Out:
# 21

# %% [markdown]
# #Division

# %%
print(a/b)
# Out:
# 0.42857142857142855
